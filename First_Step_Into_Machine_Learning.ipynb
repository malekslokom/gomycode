# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:/Users/malek/Desktop/gomycode/checkpoint3/kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [raw]
# id
# date: Date house was sold
# price: Price of the sold house
# bedrooms: Number of Bedrooms
# bathrooms: Number of bathrooms
# sqft_living: Square footage of the living space
# sqrt_lot: Square footage of the lot
# floors: Total floors in the house
# waterfront: Whether the house is on a waterfront(1: yes, 0: no)
# view: special view?
# condition: Condition of the house
# grade: unknown
# sqft_above: Square footage of house apart from basement
# sqft_basement: Square footage of the basement
# yr_built: Built year
# yr_renovated: Year when the house was renovated
# zipcode: zipcode of the house
# lat: Latitude coordinate
# long Longitude coordinate
# sqft_living15: Living room area in 2015(implies some renovations)
# sqrt_lot15: Lot area in 2015(implies some renovations)

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df["date"].unique()
# Out:
# array(['20141013T000000', '20141209T000000', '20150225T000000',
#        '20150218T000000', '20140512T000000', '20140627T000000',
#        '20150115T000000', '20150415T000000', '20150312T000000',
#        '20150403T000000', '20140527T000000', '20140528T000000',
#        '20141007T000000', '20150124T000000', '20140731T000000',
#        '20140529T000000', '20141205T000000', '20150424T000000',
#        '20140514T000000', '20140826T000000', '20140703T000000',
#        '20140516T000000', '20141120T000000', '20141103T000000',
#        '20140626T000000', '20141201T000000', '20140624T000000',
#        '20150302T000000', '20141110T000000', '20141203T000000',
#        '20140613T000000', '20141230T000000', '20150213T000000',
#        '20140620T000000', '20140715T000000', '20140811T000000',
#        '20140707T000000', '20141028T000000', '20140729T000000',
#        '20140718T000000', '20150325T000000', '20140716T000000',
#        '20150428T000000', '20150311T000000', '20140916T000000',
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
plt.figure(figsize=(14, 14))
sns.heatmap(df.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df1=df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
    'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
    'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
    'lat', 'long', 'sqft_living15', 'sqft_lot15']]
h = df1.hist(bins=25,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)

# %%
data_f1=df[["price","bedrooms","bathrooms","sqft_living","sqft_lot","floors","waterfront","view","condition","grade"]]
data_f1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade
# 0     0          3      7
# 1     0          3      7
# 2     0          3      6
# 3     0          5      7
# 4     0          3      8

# %%
sns.boxplot(x=df['floors'],y=df['price'])

# %%
sns.boxplot(x=df['bedrooms'],y=df['price'])

# %%
plt.figure(figsize=(17,7))
sns.boxplot(x=df['zipcode'],y=df['price'])

# %%
#standardization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

data_f1["price"]=scaler.fit_transform(data_f1[["price"]].values)
data_f1["bedrooms"]=scaler.fit_transform(data_f1[["bedrooms"]].values)
data_f1["sqft_living"]=scaler.fit_transform(data_f1[["sqft_living"]].values)
data_f1["sqft_lot"]=scaler.fit_transform(data_f1[["sqft_lot"]].values)
data_f1["floors"]=scaler.fit_transform(data_f1[["floors"]].values)
data_f1["bathrooms"]=scaler.fit_transform(data_f1[["bathrooms"]].values)
data_f1["waterfront"]=scaler.fit_transform(data_f1[["waterfront"]].values)
data_f1["view"]=scaler.fit_transform(data_f1[["view"]].values)
data_f1["condition"]=scaler.fit_transform(data_f1[["condition"]].values)
data_f1["grade"]=scaler.fit_transform(data_f1[["grade"]].values)
plt.figure(figsize=(8,8))

sns.boxplot(data=data_f1)
plt.xticks(rotation=90)
# Out:
# C:\Users\malek\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\malek\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\malek\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\malek\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_f2=df[["sqft_above","sqft_basement","yr_built","yr_renovated","lat","long","sqft_living15","sqft_lot15"]]

data_f2["sqft_above"]=scaler.fit_transform(data_f2[["sqft_above"]].values)
data_f2["sqft_basement"]=scaler.fit_transform(data_f2[["sqft_basement"]].values)
data_f2["yr_built"]=scaler.fit_transform(data_f2[["yr_built"]].values)
data_f2["yr_renovated"]=scaler.fit_transform(data_f2[["yr_renovated"]].values)
data_f2["lat"]=scaler.fit_transform(data_f2[["lat"]].values)
data_f2["long"]=scaler.fit_transform(data_f2[["long"]].values)
data_f2["sqft_living15"]=scaler.fit_transform(data_f2[["sqft_living15"]].values)
data_f2["sqft_lot15"]=scaler.fit_transform(data_f2[["sqft_lot15"]].values)


plt.figure(figsize=(7,7))
sns.boxplot(data=data_f2)
plt.xticks(rotation=90)
# Out:
# C:\Users\malek\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\malek\Anaconda\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\malek\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
sns.regplot(y=df["price"], x=df["condition"])

# %%
sns.distplot( df["sqft_living"] , color="skyblue")
sns.distplot( df["sqft_above"] , color="red")

# %%
sns.distplot( df["sqft_basement"] , color="skyblue")
sns.distplot( df["sqft_above"] , color="red")

# %%
plt.plot(df["sqft_living"],df["price"])
plt.xlabel("sqft_living")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
df.plot(kind='scatter', x='sqft_living', y='price',alpha = 0.5,color = 'red')
plt.xlabel('sqft_living')              # label = name of label
plt.ylabel('price')
plt.title('sqft_living price Scatter Plot')
# Out:
# Text(0.5, 1.0, 'sqft_living price Scatter Plot')

# %%
df.plot(kind='scatter', x='view', y='price',alpha = 0.5,color = 'red')
plt.xlabel('view')              # label = name of label
plt.ylabel('price')
plt.title('view price Scatter Plot')
# Out:
# Text(0.5, 1.0, 'view price Scatter Plot')

# %%
df.plot(kind='scatter', x='long', y='price',alpha = 0.5,color = 'red')
plt.xlabel('long')              # label = name of label
plt.ylabel('price')
plt.title('long price Scatter Plot')
# Out:
# Text(0.5, 1.0, 'long price Scatter Plot')

# %%
df.plot(kind='scatter', x='lat', y='price',alpha = 0.5,color = 'red')
plt.xlabel('lat')              # label = name of label
plt.ylabel('price')
plt.title('lat price Scatter Plot')
# Out:
# Text(0.5, 1.0, 'lat price Scatter Plot')

# %%
df.plot(kind='scatter', x='zipcode', y='price',alpha = 0.5,color = 'red')
plt.xlabel('zipcode')              # label = name of label
plt.ylabel('price')
plt.title('zipcode price Scatter Plot')
# Out:
# Text(0.5, 1.0, 'zipcode price Scatter Plot')

# %%
df[['price','condition']].groupby(['condition'],as_index=True).mean()
# Out:
#                    price
# condition
# 1          334431.666667
# 2          327287.145349
# 3          542012.578148
# 4          521200.390033
# 5          612418.089359

# %% [markdown]
# feature selection : we are going to drop the id and date features as they do not have a large impact on the price.

# %%
df=df.drop(["id","date"],axis=1)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
from sklearn.model_selection import train_test_split
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics


model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 63595386112.83998
# R squared 0.5053104226540768

# %% [markdown]
# sqft_living and the price have a correlation of 0.7 and gave us the highest value of R squared=0.5

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %% [markdown]
# We can deduce from the graph that linear regression is not the best model in this case because we can notice a certain curve

# %%
model.coef_
# Out:
# array([281.90496509])

# %%
from sklearn.preprocessing import PolynomialFeatures 
x=df[["yr_built","zipcode","yr_renovated","bedrooms","bathrooms","waterfront","sqft_lot","view","condition","grade","sqft_living","lat","long","sqft_lot15","sqft_living15"]]
y=df["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)
model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 38094921256.17813
# R squared 0.7036709477349942

# %% [markdown]
# After testing the combination between the different features the best R squared(0.7) was using the features "yr_built","zipcode","yr_renovated","bedrooms","bathrooms","waterfront","sqft_lot","view","condition","grade","sqft_living","lat","long","sqft_lot15","sqft_living15"

# %%
from sklearn.preprocessing import PolynomialFeatures 
x=df[["yr_built","zipcode","yr_renovated","bedrooms","bathrooms","waterfront","sqft_lot","view","condition","grade","sqft_living","lat","long","sqft_lot15","sqft_living15"]]

y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)
lg=LinearRegression()
poly=PolynomialFeatures()

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  24999089864.68836
# R squared:  0.8055395217311438

# %%
x=df["sqft_living"].values.reshape(-1,1)
y=df["price"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Polynomial regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %% [markdown]
# After trying the 3 models we find that polynomial regression is the model with the best accuracy (R squared=0.8)
